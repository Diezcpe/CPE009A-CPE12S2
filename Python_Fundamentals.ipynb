# %% [markdown]
# <a href="https://colab.research.google.com/github/Diezcpe/CPE009A-CPE12S2/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5>2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!
# Hello, world

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, world")
# Out:
# Hello, world

# %% [markdown]
# Python Variable

# %%
x = 1
a,b =0,-1
a, b, c,=0,-1,2

b ="Sally" #This is a type of string

print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b = "sally" #This is a type of string
b = int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type Function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Double Quotes or 'Single Quotes'

# %%
y = "John"
y = 'John'
print(y)
# Out:
# John

# %% [markdown]
# Case sensitive

# %%
a= 4
A= "Sally"
#A will not overwrite a
print(A)
# Out:
# Sally

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variabkes

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Python is programming is " + x)
# Out:
# Python is programming is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
10/3
x=5
y=3
sum=x+y
product=x*y
quotient=x/y
modulo=x%y
difference=x-y
exponent=x**y
print(sum)
print(product)
print(quotient)
print(modulo)
print(difference)
print(exponent)
# Out:
# 8
# 15
# 1.6666666666666667
# 2
# 2
# 125

# %% [markdown]
# Assignment Operators

# %%
s= 1
print(s)
s-5
print(s)
s-=5
print(s)
s+=5
print(s)
s*=5
print(s)
s/=5
print(s)
s%=5
print(s)
s//=5
print(s)
s**=5
print(s)
s&=5
print(s)
s|=5
print(s)
s^=5
print(s)
s>>=5
print(s)
s<<=5
print(s)
# Out:
# 1
# 1
# -4
# 1
# 5
# 1.0
# 1.0
# 0.0
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3887903640.py in <cell line: 0>()
#      17 s**=5
#      18 print(s)
# ---> 19 s&=5
#      20 print(s)
#      21 s|=5
#
# TypeError: unsupported operand type(s) for &=: 'float' and 'int'

# %% [markdown]
# Comparison Operators

# %%
t=1
u=2
t==u
print(bool(t))
t!=u
print(bool(t))
t>u
print(bool(t))
t<u
print(bool(t))
t>=u
print(bool(t))
t<=u
print(bool(t))
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# Logical Operators

# %%
n=1
n < 5 and n < 10
print(bool(n))
n < 5 or n < 4
print(bool(n))
not(n <5 and n <10)
print(bool(n))
# Out:
# True
# True
# True

# %% [markdown]
# Identity Operators

# %%
t=1
u=2

print(x is y)
print(x is not y)
# Out:
# False
# True

# %% [markdown]
# Bitwise Operators

# %%
v=2
v << 1
v<<2
15&15
# Out:
# 15
