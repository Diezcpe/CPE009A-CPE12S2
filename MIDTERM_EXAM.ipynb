# %% [markdown]
# <a href="https://colab.research.google.com/github/Diezcpe/CPE009A-CPE12S2/blob/main/MIDTERM_EXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 23

# %%
stars = 5 #rows for 1 * -5*
for i in range(1, rows + 1): #increments of asterisk or *
    for j in range(i):
        print("*", end="")
    print()#prints till the *****
stars_two = 5
for k in range(rows_two - 1, 0, -1): #decrement of *****
    for l in range(k):
        print("*", end="")
    print() #prints till the *
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# Question 24

# %%
bracket = ["({[]})","([)]", "((()))", "({)}"]
matching = ["True", "False"]
for a in bracket:
  for b in matching:

    print(a,b)
#I dont get this part poT-T, so i just like the examples during the lecture
# Out:
# ({[]}) True
# ({[]}) False
# ([)] True
# ([)] False
# ((())) True
# ((())) False
# ({)} True
# ({)} False
