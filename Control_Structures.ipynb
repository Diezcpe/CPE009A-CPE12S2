# %% [markdown]
# <a href="https://colab.research.google.com/github/Diezcpe/CPE009A-CPE12S2/blob/main/Control_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If Statement

# %%
a=12
b=100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# Elif Statement

# %%
a=12
b=12
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# Else Statements

# %%
a=200
a=33
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If Statement

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If..Else Statement

# %%
a=2
b=330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a=200
b=33
c=500
if a>b and a>c:
  print("Both conditions are True")

# %% [markdown]
# Or-at least one of the condtion is true

# %%
a=200
b=33
c=500
if a>b or a>c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# Nested If

# %%
x=41
if x>10:
  print("Above ten,")
if x>20:
  print("and also above 20!")
else:
  print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %% [markdown]
# Example 3

# %%
#PLUS 5 POINTS
print("Enter a grade: ")
grade = int(input())
if grade>=75:
  print("Passed")
elif grade==74:
  print("Remedial")
elif grade<=-1:
  print("Not Accepted!")
else:
  print("Failed")
# Out:
# Enter a grade:
# 100
# Passed
