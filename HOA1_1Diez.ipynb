# %% [markdown]
# <a href="https://colab.research.google.com/github/Diezcpe/CPE009A-CPE12S2/blob/main/HOA1_1Diez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.

# %%
value = 5
print(value)
# Out:
# 5

# %% [markdown]
# 3.

# %%
type(value)
# Out:
# int

# %%
value = 5.0
print(value)
# Out:
# 5.0

# %%
type(value)
# Out:
# float

# %% [markdown]
# a.

# %%
#a
value = 2 + 3j
print(value)
type(value)
# Out:
# (2+3j)
# complex

# %% [markdown]
# b.

# %%
#b
value = 'Hello World'
print(value)
type(value)
# Out:
# Hello World
# str

# %% [markdown]
# c.

# %%
#c
value = "Hello World"
print(value)
type(value)
# Out:
# Hello World
# str

# %% [markdown]
# d.

# %%
#d
value = True
print(value)
type(value)
# Out:
# True
# bool

# %% [markdown]
# e.

# %%
#e
value = False
print(value)
type(value)
# Out:
# False
# bool

# %% [markdown]
# f.

# %%
#f
value = [1,2,3,4,5]
print(value)
type(value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %% [markdown]
# g.

# %%
#g
value = (1,2,3,4,5)
print(value)
type(value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %% [markdown]
# h.

# %%
#h
value = {'name': 'Angela_Diez' }
print(value)
# Out:
# {'name': 'Angela_Diez'}

# %%
type(value)
# Out:
# dict

# %% [markdown]
# i.

# %%
#i
value = None
print (value)
# Out:
# None

# %%
type (value)
# Out:
# NoneType

# %% [markdown]
# 6.

# %%
value = 5

# %% [markdown]
# 7.

# %%
value2 = -6

# %% [markdown]
# 1.

# %%
print (value+value2)
# Out:
# -1

# %% [markdown]
# a.

# %%
value, value2 = 5.0, 6
print(value+value2)
# Out:
# 11.0

# %% [markdown]
# b.

# %%
value, value2 = -5, 6.1
print(value+value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# c.

# %%
value, value2 = "Hello", ' World'
print (value+value2)
# Out:
# Hello World

# %% [markdown]
# d.

# %%
value, value2=[1,2,3], [4,5,6]
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# e.

# %%
value, value2=(1,2,3), (4,5,6)
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# f.

# %%
value, value2 = {"name":"Royce"}, {"age":2}
print(value,value2)
# Out:
# {'name': 'Royce'} {'age': 2}

# %% [markdown]
# 3
# a.

# %%
value,  value2 = 30,4.
print(value*value2)
# Out:
# 120.0

# %% [markdown]
# b.

# %%
value,  value2 = 30,4.
print(value2**2)
# Out:
# 16.0

# %% [markdown]
# c.

# %%
print(value2**3)
# Out:
# 64.0

# %% [markdown]
# d.

# %%
print(value*value2+value2**2+1)
# Out:
# 137.0

# %% [markdown]
# e.

# %%
print(value/value2)
# Out:
# 7.5

# %% [markdown]
# f.

# %%
print(value%value2)
# Out:
# 2.0

# %% [markdown]
# RECIEVING INPUT DATA USING PYTHON

# %%
name = input("Enter your name: ")
weight = float(input("Enter your weight (kg): "))
height = float(input("Enter your height (meters): "))

bmi = weight / (height * height)

print("\n--- BMI Report ---")
print("Name:  ", name)
print("Weight:", weight, "kg")
print("Height:", height, "m")
print("BMI:   ", round(bmi, 2))
# Out:
# Enter your name: Angela
# Enter your weight (kg): 42
# Enter your height (meters): 1.49
#
# --- BMI Report ---
# Name:   Angela
# Weight: 42.0 kg
# Height: 1.49 m
# BMI:    18.92

# %% [markdown]
# SUPPLEMENTARY ACTIVITY

# %%
#1
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = 0.5 * base * height
print("The area is:", area)
# Out:
# Enter base: 12
# Enter height: 13
# The area is: 78.0

# %%
#2
celsius = float(input("Enter Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature inFahrenheit:", fahrenheit)
# Out:
# Enter Celsius: 45
# Temperature inFahrenheit: 113.0

# %%
#3
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
print("The distance between two points:", distance)
# Out:
# Enter x1: 4
# Enter y1: 5
# Enter x2: 6
# Enter y2: 10
# The distance between two points: 5.385164807134504
