# %% [markdown]
# <a href="https://colab.research.google.com/github/Diezcpe/CPE009A-CPE12S2/blob/main/Copy_of_Jupyter_Notebook_OOP_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. 1 and Title: Hands-on Activity 2.1 Literals and Variables </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed**:01/15/2026 |
# | **Section**: CPE12S2 | **Date Submitted**: 01/15/2026 |
# | **Student Name**: Diez, Angela May R  | **Instructor's Name**: Engr. Maria Rizette Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   List item
# 2.   List item
#
# **Intended Learning Outcome:**
#
# 1.   List item
# 2.   List item
#
# **Discussion:**
#
# (put your discussions here)
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25

# %%
print("Enther the name of the student: ")
name= str(input())
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

MHOA = float(input("MIDTERM Hands-on Activity grade: "))
MQUIZ = float(input("Enter MIDTERM Quiz grade: "))
MAS = float(input("Enter MIDTERM Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("MIDTERM CS is: ", MCS)
MEX = float(input("Enter MIDTERM Exam grade: "))
MG = (PG*(1/3)) + (2/3)*(MEX*.5 + MCS*.5)
print("MIDTERM Grade is: ", "%.2f" % MG)

FHOA = float(input("FINAL Hands-on Activity grade: "))
FQUIZ = float(input("Enter FINAL Quiz grade: "))
FAS = float(input("Enter FINAL Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("FINAL CS is: ", FCS)
FEX = float(input("Enter FINAL Exam grade: "))
FG = (MG*(1/3)) + (2/3)*(FEX*.5 + FCS*.5)
print("FINAL Grade is: ", "%.2f" % FG)
# Out:
# Enther the name of the student:
# Angela
# Enter Hands-on Activity grade: 75
# Enter Prelim Quiz grade: 90
# Enter Prelim Assignment grade: 75
# Prelim CS is:  79.5
# Enter Prelim Exam grade: 98
# Prelim Grade is:  88.75
# MIDTERM Hands-on Activity grade: 89
# Enter MIDTERM Quiz grade: 87
# Enter MIDTERM Assignment grade: 90
# MIDTERM CS is:  88.6
# Enter MIDTERM Exam grade: 95
# MIDTERM Grade is:  90.78
# FINAL Hands-on Activity grade: 90
# Enter FINAL Quiz grade: 98
# Enter FINAL Assignment grade: 85
# FINAL CS is:  91.4
# Enter FINAL Exam grade: 89
# FINAL Grade is:  90.39
